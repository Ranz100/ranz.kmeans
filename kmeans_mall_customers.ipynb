# %%
# Importing necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from google.colab import drive

# Load the dataset
drive.mount('/content/drive')
file_path = '/content/drive/MyDrive/Colab Notebooks/dataset.csv'
df = pd.read_csv(file_path)
display(df.head())

# Selecting features for clustering
features = df[['tinggi', 'berat']]

# Standardizing the features
scaler = StandardScaler()
scaled_features = scaler.fit_transform(features)

# Applying K-Means
# Choosing the number of clusters (k)
k = 5  # You can change this value based on your analysis
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10) # Added n_init to suppress warning
kmeans.fit(scaled_features)

# Adding the cluster labels to the original data
df['Cluster'] = kmeans.labels_

# Visualizing the clusters
plt.figure(figsize=(10, 6))
plt.scatter(df['tinggi'], df['berat'], c=df['Cluster'], cmap='viridis')
plt.title('K-Means Clustering')
plt.xlabel('tinggi')
plt.ylabel('berat')
plt.colorbar(label='Cluster')
plt.show()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    tinggi      jk  berat
# 0     140  wanita     44
# 1     141  wanita     44
# 2     142  wanita     44
# 3     143  wanita     45
# 4     144  wanita     45

# %%
# Print column names and data types to diagnose the loading issue
print("Column Names:")
print(df.columns)
print("\nData Types:")
df.info()
# Out:
# Column Names:
# Index(['tinggi', 'jk', 'berat', 'Cluster'], dtype='object')
#
# Data Types:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   tinggi   42 non-null     int64
#  1   jk       42 non-null     object
#  2   berat    42 non-null     int64
#  3   Cluster  42 non-null     int32
# dtypes: int32(1), int64(2), object(1)
# memory usage: 1.3+ KB
